# %%
import seaborn as sns
import draw_accuracy_graph as da
from importlib import reload
import matplotlib.pyplot as plt

# %% [markdown]
# ### tanh activation

# %%
df = da.main(['--pandas','-g','results/batch3/result_log_61c2a5_*.txt'])
# Out:
# found 280 files

# %%
fig = plt.figure(figsize=(12,6))
for k in [50, 100, 200, 400]:
    sns.kdeplot(df[df.layer_size==k].final_error,bw=0.0008, label='ls:{}'.format(k))
ax = fig.get_axes()[0]._axes
ax.set_xticklabels(['{:,.1%}'.format(x) for x in ax.get_xticks()],fontsize=14)#, fontweight='bold')
# Out:
# [Text(0, 0, '1.5%'),
#  Text(0, 0, '2.0%'),
#  Text(0, 0, '2.5%'),
#  Text(0, 0, '3.0%'),
#  Text(0, 0, '3.5%'),
#  Text(0, 0, '4.0%'),
#  Text(0, 0, '4.5%')]

# %%
fig = plt.figure(figsize=(12,6))
for k in [ 400, 800, 1200, 1600]:
    sns.kdeplot(df[df.layer_size==k].final_error,bw=0.0008, label='ls:{}'.format(k))
ax = fig.get_axes()[0]._axes
ax.set_xticklabels(['{:,.1%}'.format(x) for x in ax.get_xticks()],fontsize=14)#, fontweight='bold')
# Out:
# [Text(0, 0, '1.5%'),
#  Text(0, 0, '2.0%'),
#  Text(0, 0, '2.5%'),
#  Text(0, 0, '3.0%'),
#  Text(0, 0, '3.5%'),
#  Text(0, 0, '4.0%'),
#  Text(0, 0, '4.5%')]

# %%
df1 = da.main(['--pandas','-g','results/batch3/result_log_7720b1_*.txt'])
# Out:
# found 831 files

# %% [markdown]
# ### activation relu

# %%
fig = plt.figure(figsize=(12,6))
for k in [50, 100, 200, 400]:
    sns.kdeplot(df1[df1.layer_size==k].final_error,bw=0.0008, label='ls:{}'.format(k))
ax = fig.get_axes()[0]._axes
ax.set_xticklabels(['{:,.2%}'.format(x) for x in ax.get_xticks()],fontsize=14)#, fontweight='bold')
# Out:
# [Text(0, 0, '1.25%'),
#  Text(0, 0, '1.50%'),
#  Text(0, 0, '1.75%'),
#  Text(0, 0, '2.00%'),
#  Text(0, 0, '2.25%'),
#  Text(0, 0, '2.50%'),
#  Text(0, 0, '2.75%'),
#  Text(0, 0, '3.00%'),
#  Text(0, 0, '3.25%'),
#  Text(0, 0, '3.50%')]

# %%
plt.figure(figsize=(12,6))
for k in [ 400, 800, 1200, 1600]:
    sns.kdeplot(df1[df1.layer_size==k].final_error,bw=0.0008, label='ls:{}'.format(k))
